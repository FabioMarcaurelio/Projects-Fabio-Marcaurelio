# %%
### MATPLOTLIB ###

# %%
# Import dependencies

import numpy as np
import pandas as pd

# %%
# Import Matplotlib

import matplotlib.pyplot as plt

# %%
fig = plt.figure()
fig

# %%
ax = plt.axes() #empty box
ax
# Out:
# <Axes: >

# %%
x= [1, 2, 3, 4]
y= [1, 4, 9, 16]

plt.plot(x, y)
plt.show()

# %%
y= [1, 4, 9, 16]

plt.plot(y) # -> x will be by default [0,1,2,3,4 .... n]
plt.show()

# %%
# PLOT MULTIPLI #

y= np.array([1,2,3,4])
y
# Out:
# array([1, 2, 3, 4])

# %%
plt.plot(y)

plt.plot(y**2)

plt.plot(y**3)

plt.plot(y/2)

plt.plot(y^2)

plt.show()

# %%
# AGGIUNGI GRIGLIA #
y= np.array([1,2,3,4])

plt.plot(y)
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid() #add Grid

plt.show()

# %%
# AGGIUNGI NOME X E Y #

y= np.array([1,2,3,4])

plt.plot(y)
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid()

plt.xlabel('This is the X axis') #add X label

plt.ylabel('This is the Y axis') # add Y label

plt.show()

# %%
# AGGIUNGI TITOLO #

y= np.array([1,2,3,4])

plt.plot(y)
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid()

plt.xlabel('This is the X axis') 

plt.ylabel('This is the Y axis') 

plt.title('My First Plot') #add Title

plt.show()

# %%
# AGGIUNGI TITOLO #

y= np.array([1,2,3,4])

plt.plot(y)
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid()

plt.xlabel('This is the X axis') 

plt.ylabel('This is the Y axis') 

plt.title('My First Plot') 

plt.legend(['Y','Y^2','Y^3','Y/2','Y^2']) #add Legend

plt.show()

# %%
# AGGIUNGI COLORI #

y= np.array([1,2,3,4])

plt.plot(y,'brown') #add color
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid()

plt.xlabel('This is the X axis') 

plt.ylabel('This is the Y axis') 

plt.title('My First Plot') 

plt.legend(['Y','Y^2','Y^3','Y/2','Y^2']) #add Legend

plt.show()

# %%
# CAMBIARE DIMENSIONI #

plt.figure(figsize=(10,6)) # change size -> plt.figure(figsize=(width, length))

y= np.array([1,2,3,4])

plt.plot(y,'brown') #add color
plt.plot(y**2)
plt.plot(y**3)
plt.plot(y/2)
plt.plot(y^2)

plt.grid()

plt.xlabel('This is the X axis') 

plt.ylabel('This is the Y axis') 

plt.title('My First Plot') 

plt.legend(['Y','Y^2','Y^3','Y/2','Y^2']) #add Legend

plt.show()

# %%
plt.figure(figsize=(10,8))

#Subplots:

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1) #n rows, n columns, id subplot
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %%
x = np.linspace(0, 10, 1000)

# Plot the sinusoid function

plt.plot(x, np.sin(x), 'blue'); 
plt.show()

# %%
# Scatter Plot #

x = np.linspace(0, 10, 30)

y = np.sin(x)

plt.scatter(x, y, color = 'green')

plt.show()

# %%
# Histogram #

data1 = np.random.randn(1000)

plt.hist(data1)
plt.show()

# %%
data2 = [5. , 25. , 50. , 20.]

plt.bar(range(len(data2)), data2)

plt.show()

# %%
# boxplot #

data3 = np.random.randn(100)

plt.boxplot(data3)

plt.show();

# %%
import seaborn as sns

# %%
import warnings #ignore warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('titanic.csv') #import Titanic dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# DISTRIBUZIONE PROBABILITA' #

plt.figure(figsize=(12,6))

sns.distplot(df['Age'], hist=True)
#plt.xticks(np.linspace(0,100,10))
plt.show()

# %%
# Barplot #

plt.figure(figsize=(10,6))
sns.barplot(x="Sex", y="Survived", data=df)
plt.show()

# %%
# Swarmplot #

plt.figure(figsize=(10,6))
sns.swarmplot(x="Sex", y="Age", data=df)
plt.show()

# %%
# Boxplot #

plt.figure(figsize=(10,6))
sns.boxplot(x="Survived", y="Age", data=df)
plt.show()

# %%
# Regplot #

plt.figure(figsize=(10, 8))
sns.regplot(x="Age", y="Fare", data=df)
plt.show()

# %%
# Correlation Matrix #

df= df.drop(columns=['Ticket', 'Embarked','Name','Cabin','Name','Sex'], axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 3
#       1 # Correlation Matrix #
# ----> 3 df= df.drop(columns=['Ticket', 'Embarked','Name','Cabin','Name','Sex'], axis=1)
#       4 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
df= df.drop(columns=['Ticket', 'Embarked','Name','Cabin','Name','Sex'], axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df= df.drop(columns=['Ticket', 'Embarked','Name','Cabin','Name','Sex'], axis=1)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500

# %%
df.drop('Sex', axis=1, inplace=True) 
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.drop('Sex', axis=1, inplace=True)
#       2 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), cmap = "YlGnBu", annot=True, fmt=".2f")
plt.show()
